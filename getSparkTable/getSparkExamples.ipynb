# %% [markdown]
# # Examples:

# %% [markdown]
# ## Full function call, all are default values except for tableName

# %%
# %%time
from getSparkTable import getSparkTable
CUaddresses = getSparkTable(tableName='address_table', hostName='noahcook_db_1', databaseName='irs990', username='postgres', password='postgres234', port='5432', eins='', pandasBool=False, filterBool=False)
CUaddresses.show()
# Out:
# +---------+------------------+------------------+------------+---------------------+---------------------+------------------+---------------------+----------------+-----------------------+------------------+---------------------+---------------------+---------------+---------------------+--------------+-----------------------+-----------------------+----------------+-----------------------+------------------+
# |      ein|         object_id|RtrnHdr_TxPrdEndDt|RtrnHdr_TxYr|BsnssNm_BsnssNmLn1Txt|BsnssNm_BsnssNmLn2Txt| BsnssOffcr_PrsnNm|BsnssOffcr_PrsnTtlTxt|BsnssOffcr_PhnNm|BsnssOffcr_EmlAddrssTxt|BsnssOffcr_SgntrDt|USAddrss_AddrssLn1Txt|USAddrss_AddrssLn2Txt| USAddrss_CtyNm|USAddrss_SttAbbrvtnCd|USAddrss_ZIPCd|FrgnAddrss_AddrssLn1Txt|FrgnAddrss_AddrssLn2Txt|FrgnAddrss_CtyNm|FrgnAddrss_PrvncOrSttNm|FrgnAddrss_CntryCd|
# ...

# %% [markdown]
# ## Partial Function calls can be made if you set your URL and HostName
# * url defaults to '../data/credit_unions.csv'
# * hostName defaults to 'noahcook_db_1'
# * Pandas Bool defaults to **False** if not set
# * Filter Bool defaults to **True** if not set

# %%
# %%time
from getSparkTable import *

variables.setURL('../data/credit_unions.csv')
variables.setHostName('noahcook_db_1')
variables.setPandasBool(True)
variables.setFilterBool(True)


CUaddresses = getSparkTable(tableName='address_table')
CUaddresses.head()
# Out:
# CPU times: user 470 ms, sys: 297 ms, total: 767 ms
# Wall time: 26.3 s
#          ein           object_id RtrnHdr_TxPrdEndDt  RtrnHdr_TxYr  \
# 0  590626648  201523209349316537         2014-12-31          2014
# 1  381449460  201542879349300709         2014-12-31          2014
# 2  936024307  201503209349313360         2014-12-31          2014
# 3  381907619  201513179349300946         2014-12-31          2014
# 4  381582963  201513209349301136         2014-12-31          2014
#
#                               BsnssNm_BsnssNmLn1Txt  \
# 0                              INSIGHT CREDIT UNION
# 1  Credit Unions Chartered in the State of Michigan
# 2                  RIVERMARK COMMUNITY CREDIT UNION
# 3  Credit Unions Chartered in the State of Michigan
# 4           CREDIT UNIONS CHARTERED IN THE STATE OF
#
#                    BsnssNm_BsnssNmLn2Txt BsnssOffcr_PrsnNm  \
# 0                                   None      CINDY MORGAN
# ...

# %% [markdown]
# ## Making a Connection to the database is simplifed as well through the module

# %%
from getSparkTable import *
connection = makeConnection()

# %% [markdown]
# ## Creating a spark session is also simplified through this module

# %%
from getSparkTable import *
spark = makeSession()
